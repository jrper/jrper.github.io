# %%
print("hello")
# Out:
# hello

# %%
import pylab
x=pylab.linspace(0,4.0*pylab.pi,50)
pylab.plot(x,pylab.sin(x))

# %% [markdown]
# Testing how *this* works

# %% [markdown]
# # Welcome to a notebook
